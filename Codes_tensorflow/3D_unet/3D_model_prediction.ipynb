# %%
# !pip install segmentation-models-3D
# Out:
# Requirement already satisfied: segmentation-models-3D in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (1.0.5)
# Requirement already satisfied: keras-applications==1.0.8 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from segmentation-models-3D) (1.0.8)
# Requirement already satisfied: classification-models-3D==1.0.8 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from segmentation-models-3D) (1.0.8)
# Requirement already satisfied: keras==2.8.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from segmentation-models-3D) (2.8.0)
# Requirement already satisfied: tensorflow==2.8.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from segmentation-models-3D) (2.8.0)
# Requirement already satisfied: h5py in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from keras-applications==1.0.8->segmentation-models-3D) (3.7.0)
# Requirement already satisfied: numpy>=1.9.1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from keras-applications==1.0.8->segmentation-models-3D) (1.24.4)
# Requirement already satisfied: libclang>=9.0.1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (16.0.6)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.59.2)
# Requirement already satisfied: absl-py>=0.4.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (2.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (4.3.0)
# Requirement already satisfied: setuptools in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (63.4.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.1.2)
# Requirement already satisfied: flatbuffers>=1.12 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (23.5.26)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (2.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (0.34.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (3.20.3)
# Requirement already satisfied: gast>=0.2.1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (0.5.4)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (2.8.0.dev2021122109)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorflow==2.8.0->segmentation-models-3D) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.8.0->segmentation-models-3D) (0.37.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2.23.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (3.2.2)

# %%
# !pip install patchify
# Out:
# Requirement already satisfied: patchify in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in /Users/yichunsun/opt/anaconda3/lib/python3.9/site-packages (from patchify) (1.24.4)

# %%
import tensorflow as tf
import keras

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.8.0
# 2.8.0

# %%
import sys
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
from patchify import unpatchify
from tensorflow.keras.models import load_model
from sklearn.preprocessing import MinMaxScaler

# %%
import segmentation_models_3D as sm
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
# Get test set
test_original_3D = np.load('/Users/yichunsun/Desktop/TFM/Data/3D/3D_original_cv/cv9/3D_test_original9.npy')
test_mask_3D = np.load('/Users/yichunsun/Desktop/TFM/Data/3D/3D_original_cv/cv9/3D_test_mask9.npy')

# %%
# Back to 512x512x64
original_patches_reshaped = np.reshape(test_original_3D[:,:,:,:,0],
                                        (4, 4, 1, 128, 128, 64) )
mask_patches_reshaped = np.reshape(test_mask_3D[:,:,:,:,0],
                                        (4, 4, 1, 128, 128, 64) )
reconstructed_original = unpatchify(original_patches_reshaped, (512,512,64))
reconstructed_mask = unpatchify(mask_patches_reshaped, (512,512,64))

# %%
# Prediction DICE
def dice_coefficient(y_true, y_pred):
    intersection = np.sum(y_true * y_pred)
    union = np.sum(y_true) + np.sum(y_pred)

    dice = (2.0 * intersection) / (union + 1e-8)
    return dice

# %%
# Normalization for original 3D unet model
scaler = MinMaxScaler()
test_original_ori = scaler.fit_transform(test_original_3D.reshape(-1, test_original_3D.shape[-1])).reshape(test_original_3D.shape)

# %%
model_ori = load_model('/Users/yichunsun/Desktop/TFM/Data/3D/3D_model/withcv/vanilla_3D_cv9.h5', compile=False)

# %%
ori_prediction = model_ori.predict(test_original_ori[:,:,:,:,0])

# %%
binary_ori = (ori_prediction > 0.5).astype(int)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(test_original_3D[5,:,:,43,0], cmap='gray')
axes[0].set_title('Input Image')

axes[1].imshow(test_mask_3D[5,:,:,43,0], cmap='gray')
axes[1].set_title('True Mask')

axes[2].imshow(binary_ori[5,:,:,43,0], cmap='gray')
axes[2].set_title('Predicted Mask')
    
plt.show()

# %%
ori_patches_reshaped = np.reshape(binary_ori[:,:,:,:,0],
                                        (4, 4, 1, 128, 128, 64))
ori_reconstructed = unpatchify(ori_patches_reshaped, (512,512,64))

# %%
D_ori = dice_coefficient(reconstructed_mask, ori_reconstructed)
print("DICE of using the original structure of Unet 3D:", D_ori)
# Out:
# DICE of using the original structure of Unet 3D: 0.8970230925097908

# %%
for sample_idx in range(64):
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))

    axes[0].imshow(reconstructed_original[:,:,sample_idx], cmap='gray')
    axes[0].set_title('Input Image')

    axes[1].imshow(reconstructed_mask[:,:,sample_idx], cmap='gray')
    axes[1].set_title('True Mask')

    axes[2].imshow(ori_reconstructed[:,:,sample_idx], cmap='gray')
    axes[2].set_title('Predicted Mask')

    #save_dir = '/Users/yichunsun/Desktop/TFM/Data/3D/Results/PredictResult/Unet3D' 
    save_dir = '/Users/yichunsun/Desktop/TFM/Data/3D/Results/PredictResult/ONLYVANILA'
    os.makedirs(save_dir, exist_ok=True)

    plt.savefig(os.path.join(save_dir, f'Test_Unet3D_slice_{sample_idx}.png'))
    plt.close()

# %%
# Normalization for unet with resnet50 encoder model
preprocess_resn = sm.get_preprocessing('resnet50')
test_original_resn = preprocess_resn(test_original_3D)

# %%
model_resn = load_model('/Users/yichunsun/Desktop/TFM/Data/3D/3D_model/withcv/resnet50_3D_cv9.h5', compile=False)

# %%
resn_prediction = model_resn.predict(test_original_resn)

# %%
binary_resn = (resn_prediction > 0.5).astype(int)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(test_original_3D[5,:,:,43,0], cmap='gray')
axes[0].set_title('Input Image')

axes[1].imshow(test_mask_3D[5,:,:,43,0], cmap='gray')
axes[1].set_title('True Mask')

axes[2].imshow(binary_resn[5,:,:,43,0], cmap='gray')
axes[2].set_title('Predicted Mask')
    
plt.show()

# %%
resn_patches_reshaped = np.reshape(binary_resn[:,:,:,:,0],
                                        (4, 4, 1, 128, 128, 64))
resn_reconstructed = unpatchify(resn_patches_reshaped, (512,512,64))

# %%
D_resn = dice_coefficient(reconstructed_mask, resn_reconstructed)
print("DICE of using the resnet50 as encoder:", D_resn)
# Out:
# DICE of using the resnet50 as encoder: 0.8748310035001357

# %%
for sample_idx in range(64):
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))

    axes[0].imshow(reconstructed_original[:,:,sample_idx], cmap='gray')
    axes[0].set_title('Input Image')

    axes[1].imshow(reconstructed_mask[:,:,sample_idx], cmap='gray')
    axes[1].set_title('True Mask')

    axes[2].imshow(resn_reconstructed[:,:,sample_idx], cmap='gray')
    axes[2].set_title('Predicted Mask')

    save_dir = '/Users/yichunsun/Desktop/TFM/Data/3D/Results/PredictResult/resnet50'
    #save_dir = '/Users/yichunsun/Desktop/TFM/Data/3D/Results/PredictResult/Au_resnet50' 
    os.makedirs(save_dir, exist_ok=True)

    plt.savefig(os.path.join(save_dir, f'Test_encoder_resnet50_slice_{sample_idx}.png'))
    plt.close()

# %%
# Normalization for unet with vgg16 encoder model
preprocess_vgg = sm.get_preprocessing('vgg16')
test_original_vgg = preprocess_vgg(test_original_3D)

# %%
model_vgg = load_model('/Users/yichunsun/Desktop/TFM/Data/3D/3D_model/withcv/vgg16_3D_cv9.h5', compile=False)

# %%
vgg_prediction = model_vgg.predict(test_original_vgg)

# %%
binary_vgg = (vgg_prediction > 0.5).astype(int)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(test_original_3D[5,:,:,59,0], cmap='gray')
axes[0].set_title('Input Image')

axes[1].imshow(test_mask_3D[5,:,:,59,0], cmap='gray')
axes[1].set_title('True Mask')

axes[2].imshow(binary_vgg[5,:,:,59,0], cmap='gray')
axes[2].set_title('Predicted Mask')
    
plt.show()

# %%
vgg_patches_reshaped = np.reshape(binary_vgg[:,:,:,:,0],
                                        (4, 4, 1, 128, 128, 64))
vgg_reconstructed = unpatchify(vgg_patches_reshaped, (512,512,64))

# %%
D_vgg = dice_coefficient(reconstructed_mask, vgg_reconstructed)
print("DICE of using the vgg16 as encoder:", D_vgg)
# Out:
# DICE of using the vgg16 as encoder: 0.8717827986534352

# %%
for sample_idx in range(64):
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))

    axes[0].imshow(reconstructed_original[:,:,sample_idx], cmap='gray')
    axes[0].set_title('Input Image')

    axes[1].imshow(reconstructed_mask[:,:,sample_idx], cmap='gray')
    axes[1].set_title('True Mask')

    axes[2].imshow(vgg_reconstructed[:,:,sample_idx], cmap='gray')
    axes[2].set_title('Predicted Mask')

    #save_dir = '/Users/yichunsun/Desktop/TFM/Data/3D/Results/PredictResult/vgg16' 
    save_dir = '/Users/yichunsun/Desktop/TFM/Data/3D/Results/PredictResult/Au_vgg16'
    os.makedirs(save_dir, exist_ok=True)

    plt.savefig(os.path.join(save_dir, f'Test_encoder_vgg16_slice_{sample_idx}.png'))
    plt.close()
