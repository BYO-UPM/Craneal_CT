# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Pay attention for the python version, and keras, temsorflow

# %%
# !pip install segmentation-models

# %%
# !pip install segmentation-models-3D
# Out:
# Collecting segmentation-models-3D
#   Downloading segmentation_models_3D-1.0.6-py3-none-any.whl (33 kB)
# Collecting tensorflow==2.8.0 (from segmentation-models-3D)
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.7 MB/s eta 0:00:00
# Collecting keras==2.8.0 (from segmentation-models-3D)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 71.6 MB/s eta 0:00:00
# Collecting keras-applications==1.0.8 (from segmentation-models-3D)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.4 MB/s eta 0:00:00
# Collecting classification-models-3D==1.0.8 (from segmentation-models-3D)
#   Downloading classification_models_3D-1.0.8-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications==1.0.8->segmentation-models-3D) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications==1.0.8->segmentation-models-3D) (3.9.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (0.2.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8.0->segmentation-models-3D)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8.0->segmentation-models-3D)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 100.5 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8.0->segmentation-models-3D)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 48.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0->segmentation-models-3D) (1.59.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8.0->segmentation-models-3D) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 104.9 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 67.4 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0->segmentation-models-3D) (3.2.2)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, keras, classification-models-3D, tensorboard-data-server, keras-preprocessing, keras-applications, google-auth-oauthlib, tensorboard, tensorflow, segmentation-models-3D
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# Successfully installed classification-models-3D-1.0.8 google-auth-oauthlib-0.4.6 keras-2.8.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 segmentation-models-3D-1.0.6 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
# !pip install patchify
# Out:
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from patchify) (1.23.5)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
import tensorflow as tf
import keras

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.15.0
# 2.15.0

# %%
# Import libraries
import sys
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize
#import segmentation_models_3D as sm
from patchify import patchify, unpatchify
from keras import backend as K
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
train_original_3D = np.load('/content/drive/MyDrive/3DPart/3D/3Dnpy/3D_train_original.npy')
train_mask_3D = np.load('/content/drive/MyDrive/3DPart/3D/3Dnpy/3D_train_mask.npy')
validation_original_3D = np.load('/content/drive/MyDrive/3DPart/3D/3Dnpy/3D_validation_original.npy')
validation_mask_3D = np.load('/content/drive/MyDrive/3DPart/3D/3Dnpy/3D_validation_mask.npy')
test_original_3D = np.load('/content/drive/MyDrive/3DPart/3D/3Dnpy/3D_test_original.npy')
test_mask_3D = np.load('/content/drive/MyDrive/3DPart/3D/3Dnpy/3D_test_mask.npy')

# %%
print("Shape of the data:", train_original_3D.shape)
print("Shape of the data:", test_mask_3D.shape)
# Out:
# Shape of the data: (112, 128, 128, 64, 3)
# Shape of the data: (16, 128, 128, 64, 2)

# %%
def add_gaussian_noise(images, sigma=25):
    noisy_images = np.empty_like(images, dtype=np.float32)

    for i in range(images.shape[0]):
        gauss = np.random.normal(0, sigma, images[i].shape)
        noisy = np.clip(images[i] + gauss, 0, 255)
        noisy_images[i] = noisy

    return noisy_images.astype(np.uint8)

# %%
train_original_3D = add_gaussian_noise(train_original_3D)

# %%
# Check the patches
# Change the patch and slice
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].imshow(train_original_3D[105,:,:,33,0], cmap='gray')
axes[0].set_title('Original image')

axes[1].imshow(train_mask_3D[105,:,:,33,0], cmap='gray')
axes[1].set_title('Mask')

plt.show()

# %%
# Normalization of the data
scaler = MinMaxScaler()
#train_original_3D = scaler.fit_transform(train_original_with_gaussian_noise.reshape(-1, train_original_with_gaussian_noise.shape[-1])).reshape(train_original_with_gaussian_noise.shape)
train_original_3D = scaler.fit_transform(train_original_3D.reshape(-1, train_original_3D.shape[-1])).reshape(train_original_3D.shape)
validation_original_3D = scaler.fit_transform(validation_original_3D.reshape(-1, validation_original_3D.shape[-1])).reshape(validation_original_3D.shape)
test_original_3D = scaler.fit_transform(test_original_3D.reshape(-1, test_original_3D.shape[-1])).reshape(test_original_3D.shape)

# %%
LR = 0.0001
optim = tf.keras.optimizers.Adam(LR)

# %%
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# %%
metrics = [sm.metrics.IOUScore(threshold=0.5)]

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda, Activation

# %%
kernel_initializer =  'he_uniform'

def simple_unet_model(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    s = inputs

    #Contraction path
    c1 = Conv3D(16, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(s)
    c1 = BatchNormalization()(c1)
    c1 = Activation('relu')(c1)
    c1 = Dropout(0.1)(c1)
    c1 = Conv3D(16, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(c1)
    c1 = BatchNormalization()(c1)
    c1 = Activation('relu')(c1)
    p1 = MaxPooling3D((2, 2, 2))(c1)

    c2 = Conv3D(32, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(p1)
    c2 = BatchNormalization()(c2)
    c2 = Activation('relu')(c2)
    c2 = Dropout(0.1)(c2)
    c2 = Conv3D(32, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(c2)
    c2 = BatchNormalization()(c2)
    c2 = Activation('relu')(c2)
    p2 = MaxPooling3D((2, 2, 2))(c2)

    c3 = Conv3D(64, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(p2)
    c3 = BatchNormalization()(c3)
    c3 = Activation('relu')(c3)
    c3 = Dropout(0.2)(c3)
    c3 = Conv3D(64, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(c3)
    c3 = BatchNormalization()(c3)
    c3 = Activation('relu')(c3)
    p3 = MaxPooling3D((2, 2, 2))(c3)

    c4 = Conv3D(128, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(p3)
    c4 = BatchNormalization()(c4)
    c4 = Activation('relu')(c4)
    c4 = Dropout(0.2)(c4)
    c4 = Conv3D(128, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(c4)
    c4 = BatchNormalization()(c4)
    c4 = Activation('relu')(c4)
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(c4)

    c5 = Conv3D(256, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(p4)
    c5 = BatchNormalization()(c5)
    c5 = Activation('relu')(c5)
    c5 = Dropout(0.3)(c5)
    c5 = Conv3D(256, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(c5)
    c5 = BatchNormalization()(c5)
    c5 = Activation('relu')(c5)

    # Expansive path
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv3D(128, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(u6)
    c6 = BatchNormalization()(c6)
    c6 = Activation('relu')(c6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv3D(128, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(c6)
    c6 = BatchNormalization()(c6)
    c6 = Activation('relu')(c6)

    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv3D(64, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(u7)
    c7 = BatchNormalization()(c7)
    c7 = Activation('relu')(c7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv3D(64, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(c7)
    c7 = BatchNormalization()(c7)
    c7 = Activation('relu')(c7)

    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv3D(32, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(u8)
    c8 = BatchNormalization()(c8)
    c8 = Activation('relu')(c8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv3D(32, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(c8)
    c8 = BatchNormalization()(c8)
    c8 = Activation('relu')(c8)

    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv3D(16, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(u9)
    c9 = BatchNormalization()(c9)
    c9 = Activation('relu')(c9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv3D(16, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(c9)
    c9 = BatchNormalization()(c9)
    c9 = Activation('relu')(c9)

    outputs = Conv3D(num_classes, (1, 1, 1), activation='sigmoid')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #model.summary()

    return model

# %%
model = simple_unet_model(IMG_HEIGHT=128,
                          IMG_WIDTH=128,
                          IMG_DEPTH=64,
                          IMG_CHANNELS=1,
                          num_classes=1)

# %%
model.compile(optimizer = optim, loss=dice_loss, metrics=metrics)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 64, 1)]    0         []
#
#  conv3d (Conv3D)             (None, 128, 128, 64, 16)     448       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 64, 16)     64        ['conv3d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 128, 128, 64, 16)     0         ['batch_normalization[0][0]']
#
#  dropout (Dropout)           (None, 128, 128, 64, 16)     0         ['activation[0][0]']
#
#  conv3d_1 (Conv3D)           (None, 128, 128, 64, 16)     6928      ['dropout[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64, 16)     64        ['conv3d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 128, 128, 64, 16)     0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling3d (MaxPooling3  (None, 64, 64, 32, 16)       0         ['activation_1[0][0]']
#  D)
#
#  conv3d_2 (Conv3D)           (None, 64, 64, 32, 32)       13856     ['max_pooling3d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 32, 32)       128       ['conv3d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64, 64, 32, 32)       0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 64, 64, 32, 32)       0         ['activation_2[0][0]']
#
#  conv3d_3 (Conv3D)           (None, 64, 64, 32, 32)       27680     ['dropout_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 32, 32)       128       ['conv3d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 64, 64, 32, 32)       0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling3d_1 (MaxPoolin  (None, 32, 32, 16, 32)       0         ['activation_3[0][0]']
#  g3D)
#
#  conv3d_4 (Conv3D)           (None, 32, 32, 16, 64)       55360     ['max_pooling3d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 16, 64)       256       ['conv3d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 16, 64)       0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 32, 32, 16, 64)       0         ['activation_4[0][0]']
#
#  conv3d_5 (Conv3D)           (None, 32, 32, 16, 64)       110656    ['dropout_2[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 16, 64)       256       ['conv3d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 16, 64)       0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling3d_2 (MaxPoolin  (None, 16, 16, 8, 64)        0         ['activation_5[0][0]']
#  g3D)
#
#  conv3d_6 (Conv3D)           (None, 16, 16, 8, 128)       221312    ['max_pooling3d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 16, 16, 8, 128)       512       ['conv3d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 16, 16, 8, 128)       0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 16, 16, 8, 128)       0         ['activation_6[0][0]']
#
#  conv3d_7 (Conv3D)           (None, 16, 16, 8, 128)       442496    ['dropout_3[0][0]']
#
#  batch_normalization_7 (Bat  (None, 16, 16, 8, 128)       512       ['conv3d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 16, 16, 8, 128)       0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling3d_3 (MaxPoolin  (None, 8, 8, 4, 128)         0         ['activation_7[0][0]']
#  g3D)
#
#  conv3d_8 (Conv3D)           (None, 8, 8, 4, 256)         884992    ['max_pooling3d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 8, 8, 4, 256)         1024      ['conv3d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 8, 8, 4, 256)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 8, 8, 4, 256)         0         ['activation_8[0][0]']
#
#  conv3d_9 (Conv3D)           (None, 8, 8, 4, 256)         1769728   ['dropout_4[0][0]']
#
#  batch_normalization_9 (Bat  (None, 8, 8, 4, 256)         1024      ['conv3d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 8, 8, 4, 256)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv3d_transpose (Conv3DTr  (None, 16, 16, 8, 128)       262272    ['activation_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 8, 256)       0         ['conv3d_transpose[0][0]',
#                                                                      'activation_7[0][0]']
#
#  conv3d_10 (Conv3D)          (None, 16, 16, 8, 128)       884864    ['concatenate[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 8, 128)       512       ['conv3d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 8, 128)       0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 16, 16, 8, 128)       0         ['activation_10[0][0]']
#
#  conv3d_11 (Conv3D)          (None, 16, 16, 8, 128)       442496    ['dropout_5[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 8, 128)       512       ['conv3d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 16, 16, 8, 128)       0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv3d_transpose_1 (Conv3D  (None, 32, 32, 16, 64)       65600     ['activation_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 16, 128)      0         ['conv3d_transpose_1[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  conv3d_12 (Conv3D)          (None, 32, 32, 16, 64)       221248    ['concatenate_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 32, 32, 16, 64)       256       ['conv3d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 16, 64)       0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 32, 32, 16, 64)       0         ['activation_12[0][0]']
#
#  conv3d_13 (Conv3D)          (None, 32, 32, 16, 64)       110656    ['dropout_6[0][0]']
#
#  batch_normalization_13 (Ba  (None, 32, 32, 16, 64)       256       ['conv3d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32, 32, 16, 64)       0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv3d_transpose_2 (Conv3D  (None, 64, 64, 32, 32)       16416     ['activation_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 32, 64)       0         ['conv3d_transpose_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv3d_14 (Conv3D)          (None, 64, 64, 32, 32)       55328     ['concatenate_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 64, 64, 32, 32)       128       ['conv3d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 64, 64, 32, 32)       0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  dropout_7 (Dropout)         (None, 64, 64, 32, 32)       0         ['activation_14[0][0]']
#
#  conv3d_15 (Conv3D)          (None, 64, 64, 32, 32)       27680     ['dropout_7[0][0]']
#
#  batch_normalization_15 (Ba  (None, 64, 64, 32, 32)       128       ['conv3d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 64, 64, 32, 32)       0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv3d_transpose_3 (Conv3D  (None, 128, 128, 64, 16)     4112      ['activation_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 64, 32)     0         ['conv3d_transpose_3[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv3d_16 (Conv3D)          (None, 128, 128, 64, 16)     13840     ['concatenate_3[0][0]']
#
#  batch_normalization_16 (Ba  (None, 128, 128, 64, 16)     64        ['conv3d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 128, 128, 64, 16)     0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 128, 128, 64, 16)     0         ['activation_16[0][0]']
#
#  conv3d_17 (Conv3D)          (None, 128, 128, 64, 16)     6928      ['dropout_8[0][0]']
#
#  batch_normalization_17 (Ba  (None, 128, 128, 64, 16)     64        ['conv3d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 128, 128, 64, 16)     0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv3d_18 (Conv3D)          (None, 128, 128, 64, 1)      17        ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 5650801 (21.56 MB)
# Trainable params: 5647857 (21.54 MB)
# Non-trainable params: 2944 (11.50 KB)
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import Callback

# %%
class SavePredictionsCallback(Callback):
    def __init__(self, validation_data, save_dir):
        super(SavePredictionsCallback, self).__init__()
        self.validation_data = validation_data
        self.save_dir = save_dir

    def on_epoch_end(self, epoch, logs=None):
        predicted_masks = self.model.predict(self.validation_data[0])

        for i in range(len(self.validation_data[0])):
            self.save_or_visualize_results(
                self.validation_data[0][i],
                self.validation_data[1][i],
                predicted_masks[i],
                epoch,
                i
            )

    def save_or_visualize_results(self, input_image, true_mask, predicted_mask, epoch, sample_idx):
        fig, axes = plt.subplots(1, 3, figsize=(12, 4))

        axes[0].imshow(input_image[:,:,43], cmap='gray')
        axes[0].set_title('Input Image')

        axes[1].imshow(true_mask[:,:,43], cmap='gray')
        axes[1].set_title('True Mask')

        axes[2].imshow(predicted_mask[:,:,43], cmap='gray')
        axes[2].set_title('Predicted Mask')

        plt.savefig(os.path.join(self.save_dir, f'epoch_{epoch}_sample_{sample_idx}.png'))
        plt.close()

# %%
save_dir = '/content/drive/MyDrive/3DPart/3D/Model_training_prediction/originalunet3d_noise'
os.makedirs(save_dir, exist_ok=True)

save_predictions_callback = SavePredictionsCallback(validation_data=(validation_original_3D[:,:,:,:,0], validation_mask_3D[:,:,:,:,0]), save_dir=save_dir)

# %%
history = model.fit(train_original_3D[:,:,:,:,0],
          train_mask_3D[:,:,:,:,0],
          batch_size = 4,
          epochs = 120,
          verbose = 1,
          validation_data=(validation_original_3D[:,:,:,:,0], validation_mask_3D[:,:,:,:,0]))
          #callbacks=[save_predictions_callback])
# Out:
# Epoch 1/120
# 28/28 [==============================] - 28s 194ms/step - loss: 0.7871 - iou_score: 0.1870 - val_loss: 0.7722 - val_iou_score: 0.2058
# Epoch 2/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.6773 - iou_score: 0.4304 - val_loss: 0.7270 - val_iou_score: 0.4769
# Epoch 3/120
# 28/28 [==============================] - 5s 163ms/step - loss: 0.6457 - iou_score: 0.4619 - val_loss: 0.6852 - val_iou_score: 0.6734
# Epoch 4/120
# 28/28 [==============================] - 4s 161ms/step - loss: 0.6191 - iou_score: 0.5071 - val_loss: 0.6521 - val_iou_score: 0.6654
# Epoch 5/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.5949 - iou_score: 0.5507 - val_loss: 0.6318 - val_iou_score: 0.5755
# Epoch 6/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.5778 - iou_score: 0.5566 - val_loss: 0.5959 - val_iou_score: 0.5791
# Epoch 7/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.5600 - iou_score: 0.5580 - val_loss: 0.5795 - val_iou_score: 0.5561
# Epoch 8/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.5487 - iou_score: 0.5685 - val_loss: 0.5483 - val_iou_score: 0.5854
# Epoch 9/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.5378 - iou_score: 0.5576 - val_loss: 0.5348 - val_iou_score: 0.5707
# Epoch 10/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.5219 - iou_score: 0.5654 - val_loss: 0.5238 - val_iou_score: 0.5728
# Epoch 11/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.5148 - iou_score: 0.5719 - val_loss: 0.5171 - val_iou_score: 0.5721
# Epoch 12/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.5127 - iou_score: 0.5774 - val_loss: 0.5096 - val_iou_score: 0.6499
# Epoch 13/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4896 - iou_score: 0.5906 - val_loss: 0.5105 - val_iou_score: 0.6425
# Epoch 14/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.5031 - iou_score: 0.5831 - val_loss: 0.4997 - val_iou_score: 0.6704
# Epoch 15/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4928 - iou_score: 0.5909 - val_loss: 0.4907 - val_iou_score: 0.6480
# Epoch 16/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4860 - iou_score: 0.6078 - val_loss: 0.5095 - val_iou_score: 0.6422
# Epoch 17/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4711 - iou_score: 0.6311 - val_loss: 0.4777 - val_iou_score: 0.7095
# Epoch 18/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.4636 - iou_score: 0.6417 - val_loss: 0.4672 - val_iou_score: 0.7131
# Epoch 19/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.4817 - iou_score: 0.6121 - val_loss: 0.4491 - val_iou_score: 0.7171
# Epoch 20/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4593 - iou_score: 0.6454 - val_loss: 0.4483 - val_iou_score: 0.7324
# Epoch 21/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.4625 - iou_score: 0.6382 - val_loss: 0.4405 - val_iou_score: 0.7195
# Epoch 22/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4570 - iou_score: 0.6644 - val_loss: 0.4414 - val_iou_score: 0.7533
# Epoch 23/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4438 - iou_score: 0.6703 - val_loss: 0.4335 - val_iou_score: 0.7364
# Epoch 24/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.4525 - iou_score: 0.6717 - val_loss: 0.4294 - val_iou_score: 0.7380
# Epoch 25/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.4374 - iou_score: 0.6787 - val_loss: 0.4197 - val_iou_score: 0.7519
# Epoch 26/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.4400 - iou_score: 0.6834 - val_loss: 0.4118 - val_iou_score: 0.7510
# Epoch 27/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4416 - iou_score: 0.6693 - val_loss: 0.4025 - val_iou_score: 0.7524
# Epoch 28/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4309 - iou_score: 0.6890 - val_loss: 0.4123 - val_iou_score: 0.7355
# Epoch 29/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4249 - iou_score: 0.6849 - val_loss: 0.3953 - val_iou_score: 0.7593
# Epoch 30/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.4175 - iou_score: 0.6996 - val_loss: 0.3978 - val_iou_score: 0.7636
# Epoch 31/120
# 28/28 [==============================] - 4s 161ms/step - loss: 0.4026 - iou_score: 0.7172 - val_loss: 0.4018 - val_iou_score: 0.7538
# Epoch 32/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4122 - iou_score: 0.7039 - val_loss: 0.4092 - val_iou_score: 0.7407
# Epoch 33/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.4025 - iou_score: 0.7056 - val_loss: 0.3912 - val_iou_score: 0.7505
# Epoch 34/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.4107 - iou_score: 0.6872 - val_loss: 0.4032 - val_iou_score: 0.7734
# Epoch 35/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3996 - iou_score: 0.7160 - val_loss: 0.4082 - val_iou_score: 0.7622
# Epoch 36/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3895 - iou_score: 0.7247 - val_loss: 0.3866 - val_iou_score: 0.7469
# Epoch 37/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3780 - iou_score: 0.7383 - val_loss: 0.3829 - val_iou_score: 0.7569
# Epoch 38/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.3846 - iou_score: 0.7338 - val_loss: 0.3807 - val_iou_score: 0.7600
# Epoch 39/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3840 - iou_score: 0.7250 - val_loss: 0.3789 - val_iou_score: 0.7781
# Epoch 40/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3771 - iou_score: 0.7342 - val_loss: 0.3674 - val_iou_score: 0.7461
# Epoch 41/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3642 - iou_score: 0.7430 - val_loss: 0.3646 - val_iou_score: 0.7888
# Epoch 42/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.3663 - iou_score: 0.7470 - val_loss: 0.3784 - val_iou_score: 0.7371
# Epoch 43/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.3643 - iou_score: 0.7448 - val_loss: 0.3620 - val_iou_score: 0.7740
# Epoch 44/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3695 - iou_score: 0.7319 - val_loss: 0.3587 - val_iou_score: 0.7480
# Epoch 45/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.3567 - iou_score: 0.7545 - val_loss: 0.3639 - val_iou_score: 0.7755
# Epoch 46/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3447 - iou_score: 0.7598 - val_loss: 0.3559 - val_iou_score: 0.7979
# Epoch 47/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3462 - iou_score: 0.7550 - val_loss: 0.3593 - val_iou_score: 0.7708
# Epoch 48/120
# 28/28 [==============================] - 4s 161ms/step - loss: 0.3452 - iou_score: 0.7504 - val_loss: 0.3404 - val_iou_score: 0.7968
# Epoch 49/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3473 - iou_score: 0.7590 - val_loss: 0.3554 - val_iou_score: 0.7659
# Epoch 50/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3366 - iou_score: 0.7605 - val_loss: 0.3442 - val_iou_score: 0.8024
# Epoch 51/120
# 28/28 [==============================] - 4s 161ms/step - loss: 0.3346 - iou_score: 0.7578 - val_loss: 0.3497 - val_iou_score: 0.7582
# Epoch 52/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3341 - iou_score: 0.7525 - val_loss: 0.3341 - val_iou_score: 0.7983
# Epoch 53/120
# 28/28 [==============================] - 4s 161ms/step - loss: 0.3238 - iou_score: 0.7647 - val_loss: 0.3323 - val_iou_score: 0.7705
# Epoch 54/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3427 - iou_score: 0.7322 - val_loss: 0.3451 - val_iou_score: 0.8033
# Epoch 55/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.3150 - iou_score: 0.7769 - val_loss: 0.3422 - val_iou_score: 0.7866
# Epoch 56/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.3151 - iou_score: 0.7750 - val_loss: 0.3309 - val_iou_score: 0.8170
# Epoch 57/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3176 - iou_score: 0.7575 - val_loss: 0.3291 - val_iou_score: 0.7821
# Epoch 58/120
# 28/28 [==============================] - 4s 161ms/step - loss: 0.3166 - iou_score: 0.7622 - val_loss: 0.3238 - val_iou_score: 0.8070
# Epoch 59/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2928 - iou_score: 0.7966 - val_loss: 0.3190 - val_iou_score: 0.8029
# Epoch 60/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.3053 - iou_score: 0.7781 - val_loss: 0.3171 - val_iou_score: 0.7892
# Epoch 61/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2902 - iou_score: 0.7796 - val_loss: 0.3120 - val_iou_score: 0.8171
# Epoch 62/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2827 - iou_score: 0.7900 - val_loss: 0.3049 - val_iou_score: 0.7980
# Epoch 63/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2774 - iou_score: 0.8023 - val_loss: 0.3008 - val_iou_score: 0.7961
# Epoch 64/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2758 - iou_score: 0.7966 - val_loss: 0.3195 - val_iou_score: 0.7983
# Epoch 65/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2854 - iou_score: 0.7764 - val_loss: 0.3101 - val_iou_score: 0.8116
# Epoch 66/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2745 - iou_score: 0.7927 - val_loss: 0.2992 - val_iou_score: 0.7715
# Epoch 67/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2573 - iou_score: 0.8097 - val_loss: 0.3213 - val_iou_score: 0.7630
# Epoch 68/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2674 - iou_score: 0.7947 - val_loss: 0.2958 - val_iou_score: 0.8183
# Epoch 69/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2598 - iou_score: 0.8084 - val_loss: 0.3248 - val_iou_score: 0.7500
# Epoch 70/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2481 - iou_score: 0.8064 - val_loss: 0.2786 - val_iou_score: 0.7929
# Epoch 71/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2511 - iou_score: 0.8146 - val_loss: 0.2874 - val_iou_score: 0.8028
# Epoch 72/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2472 - iou_score: 0.8122 - val_loss: 0.2868 - val_iou_score: 0.8308
# Epoch 73/120
# 28/28 [==============================] - 4s 161ms/step - loss: 0.2624 - iou_score: 0.8037 - val_loss: 0.2730 - val_iou_score: 0.8014
# Epoch 74/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2295 - iou_score: 0.8202 - val_loss: 0.2908 - val_iou_score: 0.7780
# Epoch 75/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2367 - iou_score: 0.8195 - val_loss: 0.2666 - val_iou_score: 0.8310
# Epoch 76/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2153 - iou_score: 0.8320 - val_loss: 0.2749 - val_iou_score: 0.8175
# Epoch 77/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2236 - iou_score: 0.8229 - val_loss: 0.2554 - val_iou_score: 0.8354
# Epoch 78/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2288 - iou_score: 0.8126 - val_loss: 0.2640 - val_iou_score: 0.8219
# Epoch 79/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2090 - iou_score: 0.8403 - val_loss: 0.2465 - val_iou_score: 0.8353
# Epoch 80/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2280 - iou_score: 0.8203 - val_loss: 0.2550 - val_iou_score: 0.8067
# Epoch 81/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2234 - iou_score: 0.8235 - val_loss: 0.2485 - val_iou_score: 0.8143
# Epoch 82/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.2064 - iou_score: 0.8381 - val_loss: 0.2387 - val_iou_score: 0.8267
# Epoch 83/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1969 - iou_score: 0.8417 - val_loss: 0.2479 - val_iou_score: 0.8298
# Epoch 84/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.2058 - iou_score: 0.8349 - val_loss: 0.2386 - val_iou_score: 0.8217
# Epoch 85/120
# 28/28 [==============================] - 4s 161ms/step - loss: 0.2079 - iou_score: 0.8328 - val_loss: 0.2323 - val_iou_score: 0.8372
# Epoch 86/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1963 - iou_score: 0.8379 - val_loss: 0.2430 - val_iou_score: 0.8070
# Epoch 87/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1915 - iou_score: 0.8431 - val_loss: 0.2284 - val_iou_score: 0.8317
# Epoch 88/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1945 - iou_score: 0.8353 - val_loss: 0.2272 - val_iou_score: 0.8451
# Epoch 89/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1964 - iou_score: 0.8355 - val_loss: 0.2196 - val_iou_score: 0.8404
# Epoch 90/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1896 - iou_score: 0.8456 - val_loss: 0.2291 - val_iou_score: 0.8242
# Epoch 91/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1890 - iou_score: 0.8373 - val_loss: 0.2328 - val_iou_score: 0.8119
# Epoch 92/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1826 - iou_score: 0.8487 - val_loss: 0.2123 - val_iou_score: 0.8358
# Epoch 93/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1656 - iou_score: 0.8615 - val_loss: 0.2226 - val_iou_score: 0.8304
# Epoch 94/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1671 - iou_score: 0.8469 - val_loss: 0.2165 - val_iou_score: 0.8341
# Epoch 95/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1859 - iou_score: 0.8346 - val_loss: 0.2150 - val_iou_score: 0.8289
# Epoch 96/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1839 - iou_score: 0.8385 - val_loss: 0.2137 - val_iou_score: 0.8386
# Epoch 97/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1657 - iou_score: 0.8546 - val_loss: 0.2119 - val_iou_score: 0.8380
# Epoch 98/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1689 - iou_score: 0.8484 - val_loss: 0.2029 - val_iou_score: 0.8420
# Epoch 99/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1505 - iou_score: 0.8557 - val_loss: 0.2068 - val_iou_score: 0.8304
# Epoch 100/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1758 - iou_score: 0.8361 - val_loss: 0.2096 - val_iou_score: 0.8231
# Epoch 101/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1572 - iou_score: 0.8560 - val_loss: 0.1956 - val_iou_score: 0.8315
# Epoch 102/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1742 - iou_score: 0.8485 - val_loss: 0.2087 - val_iou_score: 0.8332
# Epoch 103/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1462 - iou_score: 0.8583 - val_loss: 0.1968 - val_iou_score: 0.8438
# Epoch 104/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1682 - iou_score: 0.8391 - val_loss: 0.1962 - val_iou_score: 0.8255
# Epoch 105/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1531 - iou_score: 0.8583 - val_loss: 0.2069 - val_iou_score: 0.8161
# Epoch 106/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1487 - iou_score: 0.8585 - val_loss: 0.1865 - val_iou_score: 0.8378
# Epoch 107/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1840 - iou_score: 0.8350 - val_loss: 0.1936 - val_iou_score: 0.8327
# Epoch 108/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1557 - iou_score: 0.8483 - val_loss: 0.1937 - val_iou_score: 0.8315
# Epoch 109/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1450 - iou_score: 0.8530 - val_loss: 0.1994 - val_iou_score: 0.8100
# Epoch 110/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1566 - iou_score: 0.8582 - val_loss: 0.1873 - val_iou_score: 0.8312
# Epoch 111/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1526 - iou_score: 0.8591 - val_loss: 0.1868 - val_iou_score: 0.8392
# Epoch 112/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1598 - iou_score: 0.8546 - val_loss: 0.1862 - val_iou_score: 0.8379
# Epoch 113/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1350 - iou_score: 0.8692 - val_loss: 0.1853 - val_iou_score: 0.8377
# Epoch 114/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1494 - iou_score: 0.8462 - val_loss: 0.1848 - val_iou_score: 0.8285
# Epoch 115/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1489 - iou_score: 0.8536 - val_loss: 0.1809 - val_iou_score: 0.8351
# Epoch 116/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1402 - iou_score: 0.8446 - val_loss: 0.1882 - val_iou_score: 0.8235
# Epoch 117/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1446 - iou_score: 0.8437 - val_loss: 0.1811 - val_iou_score: 0.8252
# Epoch 118/120
# 28/28 [==============================] - 5s 162ms/step - loss: 0.1376 - iou_score: 0.8605 - val_loss: 0.1773 - val_iou_score: 0.8347
# Epoch 119/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1504 - iou_score: 0.8658 - val_loss: 0.1733 - val_iou_score: 0.8373
# Epoch 120/120
# 28/28 [==============================] - 5s 161ms/step - loss: 0.1410 - iou_score: 0.8632 - val_loss: 0.1720 - val_iou_score: 0.8384

# %%
# Plot loss function
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='loss')
plt.plot(val_loss, label='val_loss')
plt.ylim(0, 0.9)
plt.yticks(np.arange(0, 0.9, 0.1))
plt.title('Model Loss (Vanilla Unet-3D)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training set', 'Validation set'], loc='upper right')

# %%
model.save('/content/drive/MyDrive/3DPart/3D/3DUNetModel/vanilla_unet3d_totalLoss_noise.h5')

# %%
binary_mask = (test_prediction > 0.5).astype(int)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(test_original_3D[5,:,:,33,0], cmap='gray')
axes[0].set_title('Input Image')

axes[1].imshow(test_mask_3D[5,:,:,33,0], cmap='gray')
axes[1].set_title('True Mask')

axes[2].imshow(binary_mask[5,:,:,33,0], cmap='gray')
axes[2].set_title('Predicted Mask')

plt.show()
